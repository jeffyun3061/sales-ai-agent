# %%
from dotenv import load_dotenv
import os
import requests
import json
from openai import OpenAI

load_dotenv()

class CompanyInfoExtractor:
    def __init__(self):
        self.tavily_api_key = os.getenv("TAVILY_API_KEY")
        self.openai_api_key = os.getenv("OPENAI_API_KEY")

        if not self.tavily_api_key:
            raise ValueError("❌ TAVILY_API_KEY 환경변수가 설정되지 않았습니다.")
        if not self.openai_api_key:
            raise ValueError("❌ OPENAI_API_KEY 환경변수가 설정되지 않았습니다.")

        self.openai_client = OpenAI(api_key=self.openai_api_key)

    def generate_queries(self, company_name):
        return {
            "industry": f"{company_name} 산업 분야",
            "sales": f"{company_name} 연간 매출",
            "total_funding": f"{company_name} 총 투자 유치 금액",
            "homepage": f"{company_name} 공식 홈페이지",
            "key_executive": f"{company_name} CEO",
            "address": f"{company_name} 회사 주소",
            "email": f"{company_name} 연락 이메일",
            "phone_number": f"{company_name} 연락처",
            "company_description": f"{company_name} 회사 설명",
            "products_services": f"{company_name} 주요 제품 및 서비스",
            "target_customers": f"{company_name} 주요 타겟 고객층",
            "competitors": f"{company_name} 주요 경쟁사",
            "strengths": f"{company_name} 강점",
            "business_model": f"{company_name} 비즈니스 모델"
        }

    def search_tavily(self, query, num_results=3):
        url = "https://api.tavily.com/search"
        headers = {
            "Authorization": f"Bearer {self.tavily_api_key}",
            "Content-Type": "application/json"
        }
        payload = {
            "query": query,
            "search_depth": "basic"
        }
        try:
            response = requests.post(url, headers=headers, json=payload)
            response.raise_for_status()
            results = response.json().get("results", [])[:num_results]
            
            # ✅ 반드시 이렇게: content와 url을 모두 포함
            return [
                {"url": r.get("url"), "content": r.get("content", "")}
                for r in results if "content" in r and "url" in r
            ]
            
        except requests.HTTPError as http_err:
            print(f"🔐 Tavily 인증 실패 또는 요청 오류: {http_err}")
            return []
        except Exception as e:
            print(f"⚠️ Tavily 검색 실패: {e}")
            return []
        
    def extract_info(self, company_name):
        queries = self.generate_queries(company_name)
        extracted_info = {}

        for field, query in queries.items():
            print(f"🔍 {field} → 검색 쿼리: {query}")
            sources = self.search_tavily(query)
            if not sources:
                print(f"⚠️ {field} 관련된 content 없음 (패스)")
                continue

            contents = [s["content"] for s in sources]
            urls = [s["url"] for s in sources]

            combined_content = "\n\n".join(contents)

            prompt = f"""
    당신은 회사 분석 전문가이며, 당신은 '{company_name}'에 대해 이미 내부 지식을 어느 정도 알고 있습니다.
    하지만 더 정확하고 최신 정보를 제공하기 위해 아래의 웹 검색 결과도 함께 참고해야 합니다.

    당신의 작업 목표는:
    - '{field}' 항목에 대해 정확한 정보를 JSON 형식으로 추출하는 것입니다.
    - 당신의 내부 지식과 아래 제공된 외부 웹 검색 내용을 통합해서 판단하세요.
    - 단, 최신 정보나 수치(예: 매출, 대표자 등)는 아래 텍스트를 우선적으로 신뢰하세요.
    - 정보가 명확하지 않을 경우 null 또는 "정보 없음"으로 처리하세요.
    - 최대한 정확한 정보들을 많이 제공하세요.

    회사명: "{company_name}"
    요청 항목: "{field}"

    # 참고용 외부 텍스트:
    {combined_content}

    # 응답 형식 (JSON만 반환):
    {{
    "{field}": ...
    }}
    """

            try:
                completion = self.openai_client.chat.completions.create(
                    model="gpt-4.1-mini",
                    messages=[
                        {"role": "system", "content": "You are a structured data extractor."},
                        {"role": "user", "content": prompt}
                    ],
                    temperature=0.3,
                    response_format={"type": "json_object"}
                )
                field_result = json.loads(completion.choices[0].message.content)
                extracted_info[field] = field_result
                extracted_info[f"{field}_sources"] = urls # URL 추가
            except Exception as e:
                print(f"❌ LLM 추출 실패 [{field}]: {e}")
                continue

        return extracted_info


if __name__ == "__main__":
    extractor = CompanyInfoExtractor()
    result = extractor.extract_info("토스")
    print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# 🔍 industry → 검색 쿼리: 토스 산업 분야
# 🔍 sales → 검색 쿼리: 토스 연간 매출
# 🔍 total_funding → 검색 쿼리: 토스 총 투자 유치 금액
# 🔍 homepage → 검색 쿼리: 토스 공식 홈페이지
# 🔍 key_executive → 검색 쿼리: 토스 CEO
# 🔍 address → 검색 쿼리: 토스 회사 주소
# 🔍 email → 검색 쿼리: 토스 연락 이메일
# 🔍 phone_number → 검색 쿼리: 토스 연락처
# 🔍 company_description → 검색 쿼리: 토스 회사 설명
# 🔍 products_services → 검색 쿼리: 토스 주요 제품 및 서비스
# 🔍 target_customers → 검색 쿼리: 토스 주요 타겟 고객층
# 🔍 competitors → 검색 쿼리: 토스 주요 경쟁사
# 🔍 strengths → 검색 쿼리: 토스 강점
# 🔍 business_model → 검색 쿼리: 토스 비즈니스 모델
# {
#   "industry": {
#     "industry": "금융 종합 핀테크"
#   },
#   "industry_sources": [
#     "https://rich365.co.kr/entry/비바-리퍼블리카토스-기업-정보-비바-리퍼블리카-사업분야-상장전망-실적-정리",
#     "https://blog.toss.im/article/head-inside-business",
#     "https://byline.network/2022/04/04-63/"
#   ],
#   "sales": {
#     "sales": {
#       "2023": {
#         "consolidated_revenue": "13,706억원",
#         "revenue_breakdown": {
#           "consumer_segment": "42.5%",
#           "merchant_segment": "57.5%"
#         }
#       },
#       "2024": {
#         "consolidated_revenue": "19,556억원",
#         "operating_profit": "910억원",
#         "notes": "2024년 연간 실적 기준, 창사 이래 최대 매출 및 첫 연간 흑자 달성"
#       }
#     }
#   },
#   "sales_sources": [
#     "https://www.sisajournal-e.com/news/articleView.html?idxno=410604",
#     "https://blog.toss.im/article/toss-numbers-2023",
#     "https://blog.toss.im/article/FirstFullYearNetProfit_"
#   ],
#   "total_funding": {
#     "total_funding": 530000000000
#   },
#   "total_funding_sources": [
#     "https://byline.network/2022/10/10-241/",
#     "https://news.mtn.co.kr/news-detail/2022092710403751638",
#     "https://biz.chosun.com/stock/stock_general/2022/06/29/UI3SPI6W3NEBJIYARB4JIKP5ZI/"
#   ],
#   "homepage": {
#     "homepage": "https://toss.im"
#   },
#   "homepage_sources": [
#     "https://corp.tossinvest.com/en",
#     "https://home.tossinvest.com/ko",
#     "https://toss.im/"
#   ],
#   "key_executive": {
#     "key_executive": {
#       "토스증권": {
#         "대표이사(CEO)": "김규빈",
#         "출생년도": 1989,
#         "직책": "대표이사",
#         "특이사항": "30대 중반의 젊은 CEO, 2020년 비바리퍼블리카 입사, 2022년 토스증권 제품총괄"
#       },
#       "토스(비바리퍼블리카)": {
#         "대표이사(CEO)": "정보 없음"
#       }
#     }
#   },
#   "key_executive_sources": [
#     "https://www.g-enews.com/article/Securities/2024/10/202410111750476710288320b10e_1",
#     "https://www.hankyung.com/article/202410105949i",
#     "https://www.mk.co.kr/news/stock/11136007"
#   ],
#   "address": {
#     "address": "06133 서울특별시 강남구 테헤란로 133, 4층 (역삼동, 한국타이어)"
#   },
#   "address_sources": [
#     "https://tossinvest.com/",
#     "https://www.bizno.net/article/4628601671",
#     "http://home.tossinvest.com/ko"
#   ],
#   "email": {
#     "email": "support@toss.im"
#   },
#   "email_sources": [
#     "https://sonn.tistory.com/944",
#     "https://support.toss.im/suspend",
#     "https://support.toss.im/"
#   ],
#   "phone_number": {
#     "phone_number": {
#       "토스 고객센터": "1599-4905",
#       "토스뱅크 고객센터": "1661-7654",
#       "토스증권 고객센터": "1599-7987",
#       "보이스피싱·사기 피해 신고": "1661-4905"
#     }
#   },
#   "phone_number_sources": [
#     "https://frei.pe.kr/3407",
#     "https://wageindependence1.tistory.com/entry/토스뱅크-고객센터-전화번호-상담원-연결-방법-토스-토스주식-포함",
#     "https://support.toss.im/"
#   ],
#   "company_description": {
#     "company_description": "토스는 한국 금융 산업에서 가장 빠르게 성장한 핀테크 기업으로, 대기업 계열사가 아닌 스타트업 출신임에도 불구하고 눈부신 성과를 이루어냈습니다. 월간 활성 사용자 수가 1,500만 명 이상이며, 누적 투자금액은 1조 6천억 원에 달합니다. 토스는 기존 금융 서비스의 공급자 중심 구조를 탈피하여, 사용자 중심의 혁신적인 금융 서비스를 제공하는 데 주력하고 있습니다. 특히 토스뱅크 팀은 직장인뿐만 아니라 소상공인과 저신용자도 부담 없이 이용할 수 있는 접근성 높은 은행을 목표로 하여, 금융 산업의 패러다임 변화를 선도하고 있습니다. 또한, 서현우 운영 헤드 등 전문 경영진이 전사 운영, 재무, 투자 유치 등을 총괄하며 회사의 지속적인 성장과 혁신을 이끌고 있습니다."
#   },
#   "company_description_sources": [
#     "https://toss.im/team",
#     "https://contents.premium.naver.com/ceoedu/ceocare/contents/240415171447857ax",
#     "https://blog.toss.im/article/corp-building"
#   ],
#   "products_services": {
#     "products_services": {
#       "송금_및_결제": {
#         "간편_송금": {
#           "설명": "전화번호 또는 계좌번호만으로 송금 가능",
#           "수수료": "무료 (타행 송금 포함)"
#         },
#         "결제": {
#           "온오프라인_결제": [
#             "QR코드",
#             "바코드"
#           ],
#           "토스페이_로": "쇼핑몰 및 배달앱 결제"
#         }
#       },
#       "투자_및_자산_관리": {
#         "투자_상품": [
#           "주식",
#           "펀드",
#           "비상장주식"
#         ],
#         "특징": [
#           "소액 투자 가능",
#           "초보자 가이드 제공"
#         ]
#       }
#     }
#   },
#   "products_services_sources": [
#     "https://theknowledgetree.tistory.com/entry/토스Toss-완벽-정리",
#     "https://rich365.co.kr/entry/비바-리퍼블리카토스-기업-정보-비바-리퍼블리카-사업분야-상장전망-실적-정리",
#     "http://korfin.kr/en/member/info_view.php?IDX=3"
#   ],
#   "target_customers": {
#     "target_customers": {
#       "individual_users": "일반 소비자 및 개인 사용자로, 간편 송금 및 다양한 금융 서비스를 쉽고 빠르게 이용하고자 하는 사람들",
#       "business_partners": "토스와 협업하는 B2B 파트너사 및 기관으로, 광고 사업 및 금융 서비스 연계를 통해 효율적인 마케팅과 비즈니스 성장을 추구하는 기업들",
#       "marketing_professionals": "토스애즈를 활용해 정교한 광고 전략을 수립하고 타겟 고객에게 효과적으로 접근하려는 각 기업의 마케팅 담당자"
#     }
#   },
#   "target_customers_sources": [
#     "https://folvys.com/entry/토스-기업소개-및-비즈니스-모델과-마케팅-전략",
#     "https://blog.toss.im/article/29899",
#     "https://blog.toss.im/article/head-inside-business"
#   ],
#   "competitors": {
#     "competitors": [
#       "카카오뱅크",
#       "네이버페이",
#       "카카오페이증권",
#       "로빈후드 (Robinhood)"
#     ]
#   },
#   "competitors_sources": [
#     "https://blog.naver.com/ajsy357/223760417584",
#     "https://biz.chosun.com/site/data/html_dir/2021/04/26/2021042602303.html",
#     "https://www.news2day.co.kr/article/20221122500014"
#   ],
#   "strengths": {
#     "strengths": [
#       "쉬운 설명과 물 흐르듯 자연스러운 계좌 개설 프로세스",
#       "누적 이용자 수의 꾸준한 증가 및 월간 활성 사용자 1000만 명 돌파",
#       "사용자 경험(UX)에 중점 둔 서비스 설계",
#       "토스뱅크, 토스증권 등 다양한 금융 서비스 통합 제공",
#       "혁신적이고 새로움을 추구하는 금융 플랫폼으로서의 차별화",
#       "젊은 세대의 트렌드에 민감하게 반응하며 빠르게 변화하는 시장에 적응"
#     ]
#   },
#   "strengths_sources": [
#     "https://brunch.co.kr/@1dayliterature/240",
#     "https://m.blog.naver.com/hkc6633/222146793949",
#     "https://www.nspna.com/news/?mode=view&newsid=658598"
#   ],
#   "business_model": {
#     "business_model": {
#       "고객분류": [
#         "개인 사용자",
#         "기업 고객",
#         "토스뱅크 이용자"
#       ],
#       "가치제안": [
#         "간편하고 빠른 송금 서비스",
#         "수수료 없는 토스 간 송금",
#         "토스머니 충전 및 이용 가능",
#         "사용자 친화적인 인터넷 전문은행 서비스(토스뱅크)",
#         "비대면 계좌 개설 및 금융 서비스 제공"
#       ],
#       "채널": [
#         "모바일 앱",
#         "웹 플랫폼",
#         "토스뱅크 앱"
#       ],
#       "고객관계": [
#         "비대면 서비스 제공",
#         "사용자 친화적 인터페이스",
#         "고객 지원 및 상담 서비스"
#       ],
#       "수익흐름": [
#         "토스 간 무료 송금 외 거래 상대방 송금 시 수수료 부과 및 횟수 제한",
#         "토스머니 충전 및 이용 관련 수익",
#         "토스뱅크 금융 상품 및 서비스 수익"
#       ],
#       "핵심자원": [
#         "금융 기술 플랫폼",
#         "모바일 및 웹 애플리케이션",
#         "토스뱅크 인프라",
#         "데이터 및 사용자 기반"
#       ],
#       "핵심파트너": [
#         "금융기관 및 은행",
#         "결제 네트워크",
#         "규제 기관"
#       ],
#       "핵심활동": [
#         "송금 및 결제 서비스 운영",
#         "토스머니 관리",
#         "토스뱅크 서비스 개발 및 운영",
#         "고객 지원 및 서비스 개선"
#       ],
#       "비용구조": [
#         "플랫폼 개발 및 유지보수 비용",
#         "금융 서비스 운영 비용",
#         "마케팅 및 고객 확보 비용",
#         "규제 준수 비용"
#       ]
#     }
#   },
#   "business_model_sources": [
#     "https://kbizplan.com/비즈니스모델-캔버스-예시-사례-토스-toss/",
#     "https://m.blog.naver.com/logotheraphy/223276427456",
#     "https://folvys.com/entry/토스-기업소개-및-비즈니스-모델과-마케팅-전략"
#   ]
# }
