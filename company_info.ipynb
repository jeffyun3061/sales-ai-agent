# %%
from dotenv import load_dotenv
import os
import requests
import json
from openai import OpenAI

load_dotenv()

class CompanyInfoExtractor:
    def __init__(self):
        self.tavily_api_key = os.getenv("TAVILY_API_KEY")
        self.openai_api_key = os.getenv("OPENAI_API_KEY")

        if not self.tavily_api_key:
            raise ValueError("❌ TAVILY_API_KEY 환경변수가 설정되지 않았습니다.")
        if not self.openai_api_key:
            raise ValueError("❌ OPENAI_API_KEY 환경변수가 설정되지 않았습니다.")

        self.openai_client = OpenAI(api_key=self.openai_api_key)

    def generate_queries(self, company_name):
        return {
            "industry": f"{company_name} 산업 분야",
            "sales": f"{company_name} 연간 매출",
            "total_funding": f"{company_name} 총 투자 유치 금액",
            "homepage": f"{company_name} 공식 홈페이지",
            "key_executive": f"{company_name} CEO",
            "address": f"{company_name} 회사 주소",
            "email": f"{company_name} 연락 이메일",
            "phone_number": f"{company_name} 연락처",
            "company_description": f"{company_name} 회사 설명",
            "products_services": f"{company_name} 주요 제품 및 서비스",
            "target_customers": f"{company_name} 주요 타겟 고객층",
            "competitors": f"{company_name} 주요 경쟁사",
            "strengths": f"{company_name} 강점",
            "business_model": f"{company_name} 비즈니스 모델"
        }

    def search_tavily(self, query, num_results=3):
        url = "https://api.tavily.com/search"
        headers = {
            "Authorization": f"Bearer {self.tavily_api_key}",
            "Content-Type": "application/json"
        }
        payload = {
            "query": query,
            "search_depth": "basic"
        }
        try:
            response = requests.post(url, headers=headers, json=payload)
            response.raise_for_status()
            results = response.json().get("results", [])[:num_results]
            return [
                {"url": r.get("url"), "title": r.get("title"), "content": r.get("content", "")}
                for r in results if "content" in r and "url" in r
            ]
        except Exception as e:
            print(f"⚠️ Tavily 검색 실패: {e}")
            return []

    def get_latest_news_urls(self, company_name: str, count=3):
        query = f"{company_name} 최신 뉴스"
        url = "https://api.tavily.com/search"
        headers = {
            "Authorization": f"Bearer {self.tavily_api_key}",
            "Content-Type": "application/json"
        }
        payload = {
            "query": query,
            "search_depth": "basic"
        }

        try:
            response = requests.post(url, headers=headers, json=payload)
            response.raise_for_status()
            results = response.json().get("results", [])[:count]
            return [
                {
                    "title": r.get("title", "제목 없음"),
                    "url": r.get("url", "")
                }
                for r in results
            ]
        except Exception as e:
            print(f"❌ 최신 뉴스 검색 실패: {e}")
            return []

    def extract_info(self, company_name):
        queries = self.generate_queries(company_name)
        extracted_info = {}

        for field, query in queries.items():
            print(f"🔍 {field} → 검색 쿼리: {query}")
            sources = self.search_tavily(query)
            if not sources:
                print(f"⚠️ {field} 관련된 content 없음 (패스)")
                continue

            contents = [s["content"] for s in sources]
            urls = [
                {
                    "title": s.get("title", "제목 없음"),
                    "url": s.get("url", "")
                } for s in sources
            ]

            combined_content = "\n\n".join(contents)

            prompt = f"""
            당신은 회사 분석 전문가이며, '{company_name}'에 대한 내부 지식을 보유하고 있습니다.
            그러나 더 정확하고 최신 정보를 제공하기 위해 아래의 웹 검색 결과도 함께 참고해야 합니다.

            작업 목표:
            - '{field}' 항목에 대한 정확한 정보를 JSON 형식으로 추출합니다.
            - 내부 지식과 제공된 외부 웹 검색 내용을 통합하여 판단합니다.
            - 최신 정보나 수치(예: 매출, 대표자 등)는 아래 텍스트를 우선적으로 신뢰합니다.
            - 정보가 명확하지 않을 경우 null 또는 "정보 없음"으로 처리합니다.
            - 가능한 한 정확한 정보를 많이 제공하십시오.

            회사명: "{company_name}"
            요청 항목: "{field}"

            ### 참고용 외부 텍스트:
            {combined_content}

            ### 응답 형식 (JSON만 반환):
            {{
            "{field}": ...
            }}
            """

            try:
                completion = self.openai_client.chat.completions.create(
                    model="gpt-4.1-mini",
                    messages=[
                        {"role": "system", "content": "You are a structured data extractor."},
                        {"role": "user", "content": prompt}
                    ],
                    temperature=0.3,
                    response_format={"type": "json_object"}
                )
                field_result = json.loads(completion.choices[0].message.content)
                extracted_info[field] = field_result
                extracted_info[f"{field}_sources"] = urls
            except Exception as e:
                print(f"❌ LLM 추출 실패 [{field}]: {e}")
                continue

        # 최신 뉴스 URL 리스트 추가
        # "url" 변수명 변경 가능
        extracted_info["url"] = self.get_latest_news_urls(company_name)

        return extracted_info

if __name__ == "__main__":
    extractor = CompanyInfoExtractor()
    result = extractor.extract_info("토스")
    print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# 🔍 industry → 검색 쿼리: 토스 산업 분야
# 🔍 sales → 검색 쿼리: 토스 연간 매출
# 🔍 total_funding → 검색 쿼리: 토스 총 투자 유치 금액
# 🔍 homepage → 검색 쿼리: 토스 공식 홈페이지
# 🔍 key_executive → 검색 쿼리: 토스 CEO
# 🔍 address → 검색 쿼리: 토스 회사 주소
# 🔍 email → 검색 쿼리: 토스 연락 이메일
# 🔍 phone_number → 검색 쿼리: 토스 연락처
# 🔍 company_description → 검색 쿼리: 토스 회사 설명
# 🔍 products_services → 검색 쿼리: 토스 주요 제품 및 서비스
# 🔍 target_customers → 검색 쿼리: 토스 주요 타겟 고객층
# 🔍 competitors → 검색 쿼리: 토스 주요 경쟁사
# 🔍 strengths → 검색 쿼리: 토스 강점
# 🔍 business_model → 검색 쿼리: 토스 비즈니스 모델
# {
#   "industry": {
#     "industry": "금융 종합 핀테크"
#   },
#   "industry_sources": [
#     {
#       "title": "비바 리퍼블리카(토스) 기업 정보 | 비바 리퍼블리카 사업분야 상장전망 실적 정리",
#       "url": "https://rich365.co.kr/entry/비바-리퍼블리카토스-기업-정보-비바-리퍼블리카-사업분야-상장전망-실적-정리"
#     },
#     {
#       "title": "최강의 토스 제품팀에 강력한 사업팀이 더해진다면? - 금융이 알고 싶을 때, 토스피드",
#       "url": "https://blog.toss.im/article/head-inside-business"
#     },
#     {
#       "title": "[핀테크in] 토스 사업보고서 뜯어보기 - 바이라인네트워크",
#       "url": "https://byline.network/2022/04/04-63/"
#     }
#   ],
#   "sales": {
#     "sales": {
#       "2023": {
#         "consolidated_revenue": "1조 3,706억원",
#         "consumer_segment_ratio": "42.5%",
#         "merchant_segment_ratio": "57.5%"
#       },
#       "2024": {
#         "consolidated_revenue": "1조 9,556억원",
#         "operating_profit": "910억원"
#       }
#     }
#   },
#   "sales_sources": [
#     {
#       "title": "토스, 첫 연간 흑자 전환···창사 이래 최대 매출 달성 - 시사저널e",
#       "url": "https://www.sisajournal-e.com/news/articleView.html?idxno=410604"
#     },
#     {
#       "title": "토스 사업보고서에서 눈여겨봐야 할 3가지 : 매출·Mau·Ebitda - 금융이 알고 싶을 때, 토스피드",
#       "url": "https://blog.toss.im/article/toss-numbers-2023"
#     },
#     {
#       "title": "Toss Reports Records Revenue of 2 Trillion KRW and First Full-Year Net ...",
#       "url": "https://blog.toss.im/article/FirstFullYearNetProfit_"
#     }
#   ],
#   "total_funding": {
#     "total_funding": 5300
#   },
#   "total_funding_sources": [
#     {
#       "title": "[핀테크in] 투자 빙하기, 토스는 투자를 정말 잘 받은 걸까? - 바이라인네트워크",
#       "url": "https://byline.network/2022/10/10-241/"
#     },
#     {
#       "title": "토스, 5300억 투자 유치…기업가치 9.1조원 '아시아 1위'",
#       "url": "https://news.mtn.co.kr/news-detail/2022092710403751638"
#     },
#     {
#       "title": "[단독] 토스, 기업가치 9.5조원에 시리즈g브릿지 투자 유치…5000억 모였다 - 조선비즈",
#       "url": "https://biz.chosun.com/stock/stock_general/2022/06/29/UI3SPI6W3NEBJIYARB4JIKP5ZI/"
#     }
#   ],
#   "homepage": {
#     "homepage": "https://toss.im"
#   },
#   "homepage_sources": [
#     {
#       "title": "Toss Securities Official Website - 토스증권",
#       "url": "https://corp.tossinvest.com/en"
#     },
#     {
#       "title": "토스증권 홈페이지",
#       "url": "https://home.tossinvest.com/ko"
#     },
#     {
#       "title": "Toss - 토스",
#       "url": "https://toss.im/"
#     }
#   ],
#   "key_executive": {
#     "key_executive": [
#       {
#         "name": "김규빈",
#         "position": "대표이사(CEO)",
#         "company": "토스증권",
#         "birth_year": 1989,
#         "notes": "토스증권 신임 대표이사, 30대 중반, 2023년 선임"
#       },
#       {
#         "name": "김승연",
#         "position": "전 대표이사(CEO)",
#         "company": "토스증권",
#         "notes": "사임 의사 밝힘"
#       }
#     ]
#   },
#   "key_executive_sources": [
#     {
#       "title": "토스증권, '1989년생' 30대 증권사 Ceo 탄생…국내 최연소 등극",
#       "url": "https://www.g-enews.com/article/Securities/2024/10/202410111750476710288320b10e_1"
#     },
#     {
#       "title": "1989년생 30대 증권사 Ceo 탄생…토스증권 파격 | 한국경제",
#       "url": "https://www.hankyung.com/article/202410105949i"
#     },
#     {
#       "title": "30대 증권사 Ceo 나왔다···엔지니어 출신의 토스증권 89년생 대표 - 매일경제",
#       "url": "https://www.mk.co.kr/news/stock/11136007"
#     }
#   ],
#   "address": {
#     "address": "06133 서울특별시 강남구 테헤란로 133, 4층 (역삼동, 한국타이어)"
#   },
#   "address_sources": [
#     {
#       "title": "토스증권 - 주식 투자를 더 쉽게",
#       "url": "https://tossinvest.com/"
#     },
#     {
#       "title": "토스뱅크 주식회사 - 사업자등록번호조회",
#       "url": "https://www.bizno.net/article/4628601671"
#     },
#     {
#       "title": "토스증권 홈페이지",
#       "url": "http://home.tossinvest.com/ko"
#     }
#   ],
#   "email": {
#     "email": "support@toss.im"
#   },
#   "email_sources": [
#     {
#       "title": "토스 고객센터 전화번호, 운영시간, 채팅상담 모두 알아보세요",
#       "url": "https://sonn.tistory.com/944"
#     },
#     {
#       "title": "토스 고객센터 - Toss",
#       "url": "https://support.toss.im/suspend"
#     },
#     {
#       "title": "토스 고객센터",
#       "url": "https://support.toss.im/"
#     }
#   ],
#   "phone_number": {
#     "phone_number": {
#       "토스 사용 문의": "1599-4905",
#       "토스뱅크 고객센터": "1661-7654",
#       "토스증권 고객센터": "1599-7987",
#       "보이스피싱·사기 피해 신고": "1661-4905"
#     }
#   },
#   "phone_number_sources": [
#     {
#       "title": "토스 고객센터: 전화번호, 운영시간 및 고객지원 서비스 총정리",
#       "url": "https://frei.pe.kr/3407"
#     },
#     {
#       "title": "토스뱅크 고객센터 전화번호 상담원 연결 방법(토스, 토스주식 포함)",
#       "url": "https://wageindependence1.tistory.com/entry/토스뱅크-고객센터-전화번호-상담원-연결-방법-토스-토스주식-포함"
#     },
#     {
#       "title": "토스 고객센터",
#       "url": "https://support.toss.im/"
#     }
#   ],
#   "company_description": {
#     "company_description": "토스는 한국 금융 산업에서 독특한 방식으로 성공한 핀테크 기업으로, 작은 스타트업에서 출발해 대기업 계열사가 아님에도 불구하고 빠르게 성장하여 월간 활성 사용자 1,500만 명 이상을 보유하고 있습니다. 누적 투자금액은 1조 6천억 원에 달하며, 금융 서비스의 접근성을 높여 직장인뿐만 아니라 소상공인과 저신용자도 부담 없이 이용할 수 있는 금융 플랫폼을 목표로 하고 있습니다. 또한, 토스뱅크 팀은 기존 은행 중심의 금융 산업을 공급자 중심에서 사용자 중심으로 전환하는 것을 지향하며, 혁신적인 금융 서비스를 제공하고 있습니다."
#   },
#   "company_description_sources": [
#     {
#       "title": "토스팀 소개 - Toss",
#       "url": "https://toss.im/team"
#     },
#     {
#       "title": "토스가 성공한 이유 (구조는 전략을 따른다)",
#       "url": "https://contents.premium.naver.com/ceoedu/ceocare/contents/240415171447857ax"
#     },
#     {
#       "title": "토스 운영·재무 헤드 \"제품의 성장만큼 회사의 지속가능성도 중요해요\" - 금융이 알고 싶을 때, 토스피드",
#       "url": "https://blog.toss.im/article/corp-building"
#     }
#   ],
#   "products_services": {
#     "products_services": {
#       "송금_및_결제": {
#         "간편_송금": {
#           "설명": "전화번호 또는 계좌번호만으로 송금 가능",
#           "수수료": "무료 (타행 송금 포함)"
#         },
#         "결제": {
#           "온오프라인_결제": [
#             "QR코드",
#             "바코드"
#           ],
#           "토스페이_로": "쇼핑몰 및 배달앱 결제"
#         }
#       },
#       "투자_및_자산_관리": {
#         "투자_상품": [
#           "주식",
#           "펀드",
#           "비상장주식"
#         ],
#         "특징": [
#           "소액 투자 가능",
#           "초보자 가이드 제공"
#         ],
#         "자산_관리": "정보 없음"
#       }
#     }
#   },
#   "products_services_sources": [
#     {
#       "title": "토스 (Toss) 완벽 정리 :: theknowledgetree",
#       "url": "https://theknowledgetree.tistory.com/entry/토스Toss-완벽-정리"
#     },
#     {
#       "title": "비바 리퍼블리카 (토스) 기업 정보 | 비바 리퍼블리카 사업분야 상장전망 실적 정리",
#       "url": "https://rich365.co.kr/entry/비바-리퍼블리카토스-기업-정보-비바-리퍼블리카-사업분야-상장전망-실적-정리"
#     },
#     {
#       "title": "Member - Kofin",
#       "url": "http://korfin.kr/en/member/info_view.php?IDX=3"
#     }
#   ],
#   "target_customers": {
#     "target_customers": {
#       "individual_users": "일반 개인 사용자, 특히 간편 송금 및 금융 서비스를 필요로 하는 소비자",
#       "business_partners": "토스와 협업하는 B2B 파트너사 및 기관",
#       "marketing_clients": "토스애즈를 활용하는 기업의 마케팅 담당자 및 광고주"
#     }
#   },
#   "target_customers_sources": [
#     {
#       "title": "토스 기업소개 및 비즈니스 모델과 마케팅 전략",
#       "url": "https://folvys.com/entry/토스-기업소개-및-비즈니스-모델과-마케팅-전략"
#     },
#     {
#       "title": "토스, 광고 서비스 '토스애즈' 사용자 분석 보고서 공개 - 금융이 알고 싶을 때, 토스피드",
#       "url": "https://blog.toss.im/article/29899"
#     },
#     {
#       "title": "최강의 토스 제품팀에 강력한 사업팀이 더해진다면? - 금융이 알고 싶을 때, 토스피드",
#       "url": "https://blog.toss.im/article/head-inside-business"
#     }
#   ],
#   "competitors": {
#     "competitors": [
#       "카카오뱅크",
#       "네이버페이",
#       "카카오페이증권",
#       "로빈후드 (Robinhood)"
#     ]
#   },
#   "competitors_sources": [
#     {
#       "title": "토스 toss 성공요인과 경영전략,마케팅 사례분석 / 토스 성공,실패 사례 분석과 향후전략 제시 다운로드",
#       "url": "https://blog.naver.com/ajsy357/223760417584"
#     },
#     {
#       "title": "로빈후드 vs 에이콘스… 美 경쟁 구도 따라가는 토스와 카카오페이 - 조선비즈",
#       "url": "https://biz.chosun.com/site/data/html_dir/2021/04/26/2021042602303.html"
#     },
#     {
#       "title": "핀테크 경쟁 구도 승부수 윤곽...토스·카카오페이증권, 누가 잘했나",
#       "url": "https://www.news2day.co.kr/article/20221122500014"
#     }
#   ],
#   "strengths": {
#     "strengths": [
#       "쉬운 설명과 물 흐르듯 자연스러운 계좌 개설 프로세스",
#       "누적 이용자 수의 지속적인 증가 (월간 활성 사용자 1000만 명 돌파)",
#       "사용자 경험(UX)에 중점 둔 서비스 설계",
#       "토스뱅크, 토스증권 등 다양한 금융 서비스를 통합 제공",
#       "혁신적이고 새로움을 추구하는 금융 서비스",
#       "10대 등 젊은 세대의 트렌드에 민감하게 대응하는 능력"
#     ]
#   },
#   "strengths_sources": [
#     {
#       "title": "? 토스뱅크의 강점은 상품이 아니라 사용자 경험이다.",
#       "url": "https://brunch.co.kr/@1dayliterature/240"
#     },
#     {
#       "title": "[기업's왓] 토스증권 SWOT 분석, '업계서 살아남을까'",
#       "url": "https://m.blog.naver.com/hkc6633/222146793949"
#     },
#     {
#       "title": "[Swot 분석]토스 10대서비스 틴즈, 확장성은 O·자유로움은 W-nsp통신",
#       "url": "https://www.nspna.com/news/?mode=view&newsid=658598"
#     }
#   ],
#   "business_model": {
#     "business_model": {
#       "고객분류": [
#         "토스 이용자 (개인 소비자)",
#         "비용자 및 거래 상대방",
#         "토스뱅크 고객"
#       ],
#       "가치제안": [
#         "간편하고 무료인 송금 서비스 (토스 간 이용자 대상)",
#         "비용자 거래 시 합리적인 수수료 및 횟수 제한 제공",
#         "토스머니 충전 및 이용 가능",
#         "토스뱅크를 통한 유연하고 사용 친화적인 인터넷 전문은행 서비스",
#         "비대면 계좌 개설 및 금융 서비스 제공"
#       ],
#       "채널": [
#         "모바일 앱 (토스 앱)",
#         "인터넷 전문은행 플랫폼 (토스뱅크)"
#       ],
#       "고객관계": [
#         "사용자 친화적 인터페이스 제공",
#         "비대면 서비스 지원",
#         "빠른 고객 대응 및 서비스 확장"
#       ],
#       "수익흐름": [
#         "비용자 및 거래 상대방으로부터의 수수료 수입",
#         "토스머니 충전 및 이용 관련 수익",
#         "토스뱅크 금융 상품 및 서비스 수익"
#       ],
#       "핵심자원": [
#         "토스 모바일 플랫폼 및 기술 인프라",
#         "토스뱅크 인터넷 전문은행 인프라",
#         "금융 데이터 및 사용자 기반"
#       ],
#       "핵심파트너": [
#         "금융기관 및 은행",
#         "결제 네트워크 및 송금 시스템",
#         "기술 및 보안 서비스 제공자"
#       ],
#       "핵심활동": [
#         "송금 서비스 운영 및 관리",
#         "토스머니 충전 및 결제 서비스 제공",
#         "토스뱅크 금융 서비스 개발 및 운영",
#         "고객 지원 및 서비스 개선"
#       ],
#       "비용구조": [
#         "플랫폼 운영 및 유지 비용",
#         "금융 서비스 개발 및 인프라 비용",
#         "고객 지원 및 마케팅 비용",
#         "보안 및 규제 준수 비용"
#       ]
#     }
#   },
#   "business_model_sources": [
#     {
#       "title": "비즈니스모델 캔버스 예시 사례 : 토스 (Toss)",
#       "url": "https://kbizplan.com/비즈니스모델-캔버스-예시-사례-토스-toss/"
#     },
#     {
#       "title": "토스 TOSS (비바리퍼블리카) 기업분석 및 비지니스모델 (ft.인터넷뱅크, 뱅크런) : 네이버 블로그",
#       "url": "https://m.blog.naver.com/logotheraphy/223276427456"
#     },
#     {
#       "title": "토스 기업소개 및 비즈니스 모델과 마케팅 전략",
#       "url": "https://folvys.com/entry/토스-기업소개-및-비즈니스-모델과-마케팅-전략"
#     }
#   ],
#   "url": [
#     {
#       "title": "토스, 첫 연간 흑자 전환…창사 이래 최대 매출 달성 - 매일경제",
#       "url": "https://www.mk.co.kr/news/economy/11276410"
#     },
#     {
#       "title": "\"노하우 다 퍼주고 지갑·카드 멸종시킬 것\"…'10주년' 토스, 파격 선언 - 매일경제",
#       "url": "https://www.mk.co.kr/news/economy/11250964"
#     },
#     {
#       "title": "토스 \"금융 넘어 글로벌 슈퍼앱 진화…플랫폼 툴 외부 공개\"(종합) | 연합뉴스",
#       "url": "https://www.yna.co.kr/view/AKR20250226054551017"
#     }
#   ]
# }
